# %%
pip install twilio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from twilio.rest import Client

# Your Twilio credentials
account_sid ='VAb51e0736f7c8911bb3260a01c66819e8'
auth_token = 'your_auth_token'
twilio_phone_number = 'your_twilio_phone_number'

# Initialize the Twilio client
client = Client(account_sid, auth_token)

def send_otp(to_phone_number, otp_code):
    message = client.messages.create(
        body=f"Your OTP is {otp_code}",
        from_=twilio_phone_number,
        to=to_phone_number
    )
    print(f"Sent OTP to {to_phone_number}: {otp_code}")

if __name__ == "__main__":
    # Example usage
    to_phone_number = '+918143244752'  # Replace with the recipient's phone number
    otp_code = '862170'  # Replace with the actual OTP code
    send_otp(to_phone_number, otp_code)
# Out:
# ---------------------------------------------------------------------------
# TwilioRestException                       Traceback (most recent call last)
# Cell In[3], line 23
#      21 to_phone_number = '+918143244752'  # Replace with the recipient's phone number
#      22 otp_code = '862170'  # Replace with the actual OTP code
# ---> 23 send_otp(to_phone_number, otp_code)
#
# Cell In[3], line 12, in send_otp(to_phone_number, otp_code)
#      11 def send_otp(to_phone_number, otp_code):
# ---> 12     message = client.messages.create(
#      13         body=f"Your OTP is {otp_code}",
#      14         from_=twilio_phone_number,
#      15         to=to_phone_number
#      16     )
#      17     print(f"Sent OTP to {to_phone_number}: {otp_code}")
#
# ...
